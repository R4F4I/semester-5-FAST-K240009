# %%
# !kaggle competitions download -c playground-series-s6e8

# 3. Create a folder and unzip the data
# !mkdir -p data
# !unzip -o playground-series-s6e8.zip -d data/

# 4. List the downloaded files
# !ls -lh data/
